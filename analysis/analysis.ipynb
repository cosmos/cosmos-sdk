# %%
from analysis.read_otel import load_otel_runs
from analysis.analysis import block_summary, plot_block_durations
import pandas as pd

# %%
runs = load_otel_runs("/Users/arc/iavl-bench-data/sims")

# %%
pd.DataFrame(
    [{'run': name, 'duration': block_summary(run).total_duration_seconds} for name, run in runs.items()]).set_index(
    'run')
# Out:
#                   duration
# run
# iavlx-no-fsync  161.325176
# iavl1           208.354362
# iavlx           178.002386

# %%
plot_block_durations(runs)

# %%
plot_block_durations(runs, span_name='Commit')
